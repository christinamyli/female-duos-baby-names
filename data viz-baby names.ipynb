# %%
import requests
import pandas as pd

# %%
ls
# Out:
# Copy of SSA Baby Names - All SSA Data.csv
# data viz-baby names.ipynb

# %%
df = pd.read_csv("Copy of SSA Baby Names - All SSA Data.csv")
df
# Out:
#          Year       Name Sex  Count
# 0        1880       Mary   F   7065
# 1        1880       Anna   F   2604
# 2        1880       Emma   F   2003
# 3        1880  Elizabeth   F   1939
# 4        1880     Minnie   F   1746
# ...       ...        ...  ..    ...
# 2116835  2023      Zyell   M      5
# 2116836  2023       Zyen   M      5
# 2116837  2023     Zymirr   M      5
# 2116838  2023     Zyquan   M      5
# 2116839  2023      Zyrin   M      5
#
# [2116840 rows x 4 columns]

# %%
spring_df = df[df['Name'] == 'Spring']
spring_df = spring_df[spring_df['Sex'] == 'F']
spring_df
# Out:
#          Year    Name Sex  Count
# 477017   1951  Spring   F      7
# 484572   1952  Spring   F     30
# 495372   1953  Spring   F     27
# 505868   1954  Spring   F     38
# 516796   1955  Spring   F     41
# ...       ...     ...  ..    ...
# 1964902  2019  Spring   F     17
# 1995500  2020  Spring   F     23
# 2025215  2021  Spring   F     42
# 2060151  2022  Spring   F     17
# 2091511  2023  Spring   F     19
#
# [73 rows x 4 columns]

# %%
# spring_df[spring_df['Sex'] == 'M']
# Out:
# Empty DataFrame
# Columns: [Year, Name, Sex, Count]
# Index: []

# %%
# spring_df.dtypes
# Out:
# Year      int64
# Name     object
# Sex      object
# Count     int64
# dtype: object

# %%
spring_chart = alt.Chart(spring_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1970, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 4500])),
    color='Sex',
).interactive()

spring_chart
# Out:
# alt.Chart(...)

# %%
seasons_df = spring_df[spring_df['Year'] >= 1970]
seasons_df
# Out:
#          Year    Name Sex  Count
# 697906   1970  Spring   F    100
# 712860   1971  Spring   F     81
# 728015   1972  Spring   F     91
# 743471   1973  Spring   F     86
# 759203   1974  Spring   F     85
# 775008   1975  Spring   F    162
# 791750   1976  Spring   F    251
# 809357   1977  Spring   F    182
# 827571   1978  Spring   F    174
# 845831   1979  Spring   F    176
# 865091   1980  Spring   F    128
# 884635   1981  Spring   F    113
# 904500   1982  Spring   F     76
# 924218   1983  Spring   F     71
# 943730   1984  Spring   F     66
# 963816   1985  Spring   F     46
# 984122   1986  Spring   F     41
# 1006053  1987  Spring   F     24
# 1026320  1988  Spring   F     42
# 1049201  1989  Spring   F     35
# 1072519  1990  Spring   F     45
# 1098226  1991  Spring   F     30
# 1124549  1992  Spring   F     21
# 1149799  1993  Spring   F     22
# 1175111  1994  Spring   F     27
# 1200768  1995  Spring   F     30
# 1227120  1996  Spring   F     28
# ...

# %%
summer_df = df[df['Name'] == 'Summer']
summer_df = summer_df[summer_df['Sex'] == 'F']
summer_df
# Out:
#          Year    Name Sex  Count
# 457632   1949  Summer   F      5
# 485287   1952  Summer   F     18
# 495785   1953  Summer   F     20
# 507076   1954  Summer   F     16
# 517585   1955  Summer   F     22
# ...       ...     ...  ..    ...
# 1958110  2019  Summer   F   1636
# 1990191  2020  Summer   F   1812
# 2021698  2021  Summer   F   1954
# 2053395  2022  Summer   F   1862
# 2085298  2023  Summer   F   1960
#
# [73 rows x 4 columns]

# %%
summer_df = summer_df[summer_df['Year'] >= 1970]
summer_df
# Out:
#          Year    Name Sex  Count
# 697917   1970  Summer   F     99
# 712390   1971  Summer   F    156
# 727550   1972  Summer   F    197
# 742994   1973  Summer   F    184
# 758462   1974  Summer   F    314
# 774475   1975  Summer   F    785
# 791354   1976  Summer   F   1072
# 808649   1977  Summer   F   2447
# 826861   1978  Summer   F   1918
# 845105   1979  Summer   F   1860
# 864157   1980  Summer   F   1754
# 883634   1981  Summer   F   1544
# 903148   1982  Summer   F   1262
# 922853   1983  Summer   F   1166
# 942265   1984  Summer   F   1212
# 961790   1985  Summer   F   1167
# 981887   1986  Summer   F   1127
# 1002567  1987  Summer   F   1042
# 1023991  1988  Summer   F    987
# 1046394  1989  Summer   F    910
# 1070154  1990  Summer   F   1021
# 1094888  1991  Summer   F    984
# 1119969  1992  Summer   F   1101
# 1145327  1993  Summer   F   1617
# 1171256  1994  Summer   F   2238
# 1197265  1995  Summer   F   2124
# 1223331  1996  Summer   F   2345
# ...

# %%
seasons_df = pd.concat([seasons_df, summer_df], ignore_index=True)
seasons_df
# Out:
#      Year    Name Sex  Count
# 0    1970  Spring   F    100
# 1    1971  Spring   F     81
# 2    1972  Spring   F     91
# 3    1973  Spring   F     86
# 4    1974  Spring   F     85
# ..    ...     ...  ..    ...
# 103  2019  Summer   F   1636
# 104  2020  Summer   F   1812
# 105  2021  Summer   F   1954
# 106  2022  Summer   F   1862
# 107  2023  Summer   F   1960
#
# [108 rows x 4 columns]

# %%
ult_df.to_csv('seasons_df.csv', index=False)

# %%
summer_chart = alt.Chart(summer_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1960, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 4500])),
    color='Sex',
).interactive()

summer_chart
# Out:
# alt.Chart(...)

# %%
autumn_df = df[df['Name'] == 'Autumn']
autumn_df = autumn_df[autumn_df['Sex'] == 'F']
autumn_df
# Out:
#          Year    Name Sex  Count
# 91381    1910  Autumn   F      5
# 96070    1911  Autumn   F      5
# 107349   1913  Autumn   F      7
# 115417   1914  Autumn   F      5
# 124052   1915  Autumn   F      5
# ...       ...     ...  ..    ...
# 1958013  2019  Autumn   F   3276
# 1990122  2020  Autumn   F   3133
# 2021623  2021  Autumn   F   3486
# 2053313  2022  Autumn   F   3214
# 2085232  2023  Autumn   F   3001
#
# [108 rows x 4 columns]

# %%
autumn_df = autumn_df[autumn_df['Year'] >= 1970]
autumn_df
# Out:
#          Year    Name Sex  Count
# 697479   1970  Autumn   F    200
# 712172   1971  Autumn   F    251
# 727376   1972  Autumn   F    302
# 742770   1973  Autumn   F    318
# 758275   1974  Autumn   F    618
# 774462   1975  Autumn   F    840
# 791383   1976  Autumn   F    930
# 808758   1977  Autumn   F   1092
# 826918   1978  Autumn   F   1308
# 845135   1979  Autumn   F   1498
# 864178   1980  Autumn   F   1530
# 883639   1981  Autumn   F   1495
# 903130   1982  Autumn   F   1427
# 922842   1983  Autumn   F   1254
# 942270   1984  Autumn   F   1187
# 961775   1985  Autumn   F   1221
# 981888   1986  Autumn   F   1122
# 1002513  1987  Autumn   F   1441
# 1023902  1988  Autumn   F   1666
# 1046294  1989  Autumn   F   1482
# 1070060  1990  Autumn   F   1652
# 1094773  1991  Autumn   F   1748
# 1119885  1992  Autumn   F   1783
# 1145296  1993  Autumn   F   2086
# 1171232  1994  Autumn   F   2718
# 1197222  1995  Autumn   F   2980
# 1223298  1996  Autumn   F   3110
# ...

# %%
seasons_df = pd.concat([seasons_df, autumn_df], ignore_index=True)
seasons_df
# Out:
#      Year    Name Sex  Count
# 0    1970  Spring   F    100
# 1    1971  Spring   F     81
# 2    1972  Spring   F     91
# 3    1973  Spring   F     86
# 4    1974  Spring   F     85
# ..    ...     ...  ..    ...
# 157  2019  Autumn   F   3276
# 158  2020  Autumn   F   3133
# 159  2021  Autumn   F   3486
# 160  2022  Autumn   F   3214
# 161  2023  Autumn   F   3001
#
# [162 rows x 4 columns]

# %%
autumn_chart = alt.Chart(autumn_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1960, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 4500])),
    color='Sex',
).interactive()

autumn_chart
# Out:
# alt.Chart(...)

# %%
winter_df = df[df['Name'] == 'Winter']
winter_df = winter_df[winter_df['Sex'] == 'F']
winter_df
# Out:
#          Year    Name Sex  Count
# 510805   1954  Winter   F      5
# 591006   1961  Winter   F      6
# 616492   1963  Winter   F      5
# 628926   1964  Winter   F      5
# 663675   1967  Winter   F      7
# 691678   1969  Winter   F      5
# 704718   1970  Winter   F      6
# 734105   1972  Winter   F      7
# 748310   1973  Winter   F      9
# 764173   1974  Winter   F      9
# 781332   1975  Winter   F      8
# 794534   1976  Winter   F     21
# 811366   1977  Winter   F     29
# 827718   1978  Winter   F    137
# 845661   1979  Winter   F    241
# 865027   1980  Winter   F    140
# 884663   1981  Winter   F    109
# 904213   1982  Winter   F    101
# 923955   1983  Winter   F     92
# 943539   1984  Winter   F     78
# 963646   1985  Winter   F     52
# 983441   1986  Winter   F     65
# 1003997  1987  Winter   F     73
# 1025743  1988  Winter   F     60
# 1047977  1989  Winter   F     71
# 1071760  1990  Winter   F     76
# 1096533  1991  Winter   F     73
# ...

# %%
winter_df = winter_df[winter_df['Year'] >= 1970]
winter_df
# Out:
#          Year    Name Sex  Count
# 704718   1970  Winter   F      6
# 734105   1972  Winter   F      7
# 748310   1973  Winter   F      9
# 764173   1974  Winter   F      9
# 781332   1975  Winter   F      8
# 794534   1976  Winter   F     21
# 811366   1977  Winter   F     29
# 827718   1978  Winter   F    137
# 845661   1979  Winter   F    241
# 865027   1980  Winter   F    140
# 884663   1981  Winter   F    109
# 904213   1982  Winter   F    101
# 923955   1983  Winter   F     92
# 943539   1984  Winter   F     78
# 963646   1985  Winter   F     52
# 983441   1986  Winter   F     65
# 1003997  1987  Winter   F     73
# 1025743  1988  Winter   F     60
# 1047977  1989  Winter   F     71
# 1071760  1990  Winter   F     76
# 1096533  1991  Winter   F     73
# 1121543  1992  Winter   F     79
# 1146840  1993  Winter   F     89
# 1172482  1994  Winter   F    122
# 1198371  1995  Winter   F    135
# 1224271  1996  Winter   F    173
# 1250693  1997  Winter   F    177
# ...

# %%
seasons_df = pd.concat([seasons_df, winter_df], ignore_index=True)
seasons_df
# Out:
#      Year    Name Sex  Count
# 0    1970  Spring   F    100
# 1    1971  Spring   F     81
# 2    1972  Spring   F     91
# 3    1973  Spring   F     86
# 4    1974  Spring   F     85
# ..    ...     ...  ..    ...
# 210  2019  Winter   F    981
# 211  2020  Winter   F   1007
# 212  2021  Winter   F   1007
# 213  2022  Winter   F   1048
# 214  2023  Winter   F    826
#
# [215 rows x 4 columns]

# %%
seasons_df.to_csv('seasons_df.csv', index=False)

# %%
seasons_df.to_excel('seasons_df.xlsx', index=False)

# %%
winter_chart = alt.Chart(winter_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1960, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 4500])),
    color='Sex',
).interactive()

winter_chart
# Out:
# alt.Chart(...)

# %%
df[df['Name'] == 'Ronald']
# Out:
#          Year    Name Sex  Count
# 7982     1883  Ronald   M      6
# 9917     1884  Ronald   M     11
# 14551    1886  Ronald   M     13
# 17168    1887  Ronald   M      8
# 19495    1888  Ronald   M     15
# ...       ...     ...  ..    ...
# 1976457  2019  Ronald   M    539
# 2008083  2020  Ronald   M    502
# 2039748  2021  Ronald   M    501
# 2071461  2022  Ronald   M    529
# 2103302  2023  Ronald   M    456
#
# [214 rows x 4 columns]

# %%
df[(df['Name'] == 'Reagan') & (df['Sex'] == 'M')]
# Out:
#          Year    Name Sex  Count
# 111664   1913  Reagan   M      5
# 128964   1915  Reagan   M      5
# 136926   1916  Reagan   M     10
# 146772   1917  Reagan   M     10
# 157574   1918  Reagan   M      8
# ...       ...     ...  ..    ...
# 1976980  2019  Reagan   M    195
# 2008723  2020  Reagan   M    160
# 2040378  2021  Reagan   M    164
# 2072216  2022  Reagan   M    143
# 2104218  2023  Reagan   M    115
#
# [102 rows x 4 columns]

# %%
df[(df['Name'] == 'Reagan') & (df['Sex'] == 'F')]
# Out:
#          Year    Name Sex  Count
# 531524   1956  Reagan   F      7
# 612824   1963  Reagan   F     12
# 623859   1964  Reagan   F     22
# 637672   1965  Reagan   F     11
# 648851   1966  Reagan   F     15
# ...       ...     ...  ..    ...
# 1958033  2019  Reagan   F   2751
# 1990154  2020  Reagan   F   2369
# 2021683  2021  Reagan   F   2239
# 2053389  2022  Reagan   F   1982
# 2085325  2023  Reagan   F   1721
#
# [62 rows x 4 columns]

# %%
rose_df = df[df['Name'] == 'Rose']
rose_df['Count'].mean()
# Out:
# 1952.2470588235294

# %%
daisy_df = df[df['Name'] == 'Daisy']
daisy_df['Count'].mean()
# Out:
# 711.4697674418604

# %%
violet_df = df[df['Name'] == 'Violet']
violet_df['Count'].mean()
# Out:
# 945.6850828729282

# %%
lily_df = df[df['Name'] == 'Lily']
lily_df['Count'].mean()
# Out:
# 1098.2111801242236

# %%
ivy_df = df[df['Name'] == 'Ivy']
ivy_df['Count'].mean()
# Out:
# 265.10526315789474

# %%
iris_df = df[df['Name'] == 'Iris']
iris_df['Count'].mean()
# Out:
# 418.24122807017545

# %%
melody_df = df[df['Name'] == 'Melody']
melody_df
# Out:
#          Year    Name Sex  Count
# 114828   1914  Melody   F      7
# 174949   1920  Melody   F      5
# 196589   1922  Melody   F      5
# 216765   1924  Melody   F      7
# 228108   1925  Melody   F      6
# ...       ...     ...  ..    ...
# 1958049  2019  Melody   F   2455
# 1990146  2020  Melody   F   2517
# 2021670  2021  Melody   F   2460
# 2053351  2022  Melody   F   2558
# 2085260  2023  Melody   F   2557
#
# [126 rows x 4 columns]

# %%
harmony_df = df[(df['Name'] == 'Harmony') & (df['Sex'] == 'F')]
harmony_df
# Out:
#          Year     Name Sex  Count
# 124280   1915  Harmony   F      5
# 184401   1921  Harmony   F      7
# 456073   1949  Harmony   F      7
# 509063   1954  Harmony   F      7
# 532608   1956  Harmony   F      5
# ...       ...      ...  ..    ...
# 1958100  2019  Harmony   F   1707
# 1990215  2020  Harmony   F   1634
# 2021755  2021  Harmony   F   1507
# 2053457  2022  Harmony   F   1370
# 2085388  2023  Harmony   F   1297
#
# [67 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# %%
# melody_df.plot.scatter(x='Year',y='Count')
x = melody_df['Year']
y = melody_df['Count']
plt.title('Melody Trend')
plt.scatter(x, y, color='pink')
plt.ylim(0,3000)
plt.savefig("melody.svg")
plt.show()

# %%
ls
# Out:
# Copy of SSA Baby Names - All SSA Data.csv
# data viz-baby names.ipynb
# melody.svg

# %%
# harmony_df.plot.scatter(x='Year',y='Count')
plt.scatter(harmony_df['Year'], harmony_df['Count'])
plt.ylim(0,3000)
# Out:
# (0.0, 3000.0)

# %%
pip install "altair[all]"
# Out:
# ...
#   Using cached altair_tiles-0.3.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached anywidget-0.9.13-py3-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached pyarrow-16.1.0-cp311-cp311-macosx_10_15_x86_64.whl.metadata (3.0 kB)
# ...
#   Using cached vegafusion-1.6.9-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached vl_convert_python-1.5.0.tar.gz (4.8 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#
#       Cargo, the Rust package manager, is not installed or is not on PATH.
#       This package requires Rust and Cargo to compile extensions. Install it through
#       the system's package manager or via https://rustup.rs/
#
#       Checking for Rust toolchain....
#       [end of output]
#
# ...

# %%
pip install altair vega_datasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
melody_df
# Out:
#          Year    Name Sex  Count
# 114828   1914  Melody   F      7
# 174949   1920  Melody   F      5
# 196589   1922  Melody   F      5
# 216765   1924  Melody   F      7
# 228108   1925  Melody   F      6
# ...       ...     ...  ..    ...
# 1958049  2019  Melody   F   2455
# 1990146  2020  Melody   F   2517
# 2021670  2021  Melody   F   2460
# 2053351  2022  Melody   F   2558
# 2085260  2023  Melody   F   2557
#
# [126 rows x 4 columns]

# %%
# # import altair with an abbreviated alias
# import altair as alt

# # load a sample dataset as a pandas DataFrame
# from vega_datasets import data
# melody_df = data.melody_df()

# %%
pip install altair_saver
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U altair_viewer
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import altair as alt

chart = alt.Chart(melody_df).mark_point().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 3000])),
    color='Sex',
).interactive()

chart
# Out:
# alt.Chart(...)

# %%
chart2 = alt.Chart(harmony_df).mark_point().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0,3000])),
    color='Sex',
).interactive()

chart2
# Out:
# alt.Chart(...)

# %%
ls
# Out:
# Copy of SSA Baby Names - All SSA Data.csv
# data viz-baby names.ipynb
# melody.svg

# %%
rose_rank_df = pd.read_excel("Rose - Name Ranking.xlsx")
rose_rank_df['Rank'].mean()
# Out:
# 242.91666666666666

# %%
lily_rank_df = pd.read_excel("Lily - Name Ranking.xlsx")
lily_rank_df['Rank'].mean()
# Out:
# 38.916666666666664

# %%
violet_rank_df = pd.read_excel("Violet - Name Ranking.xlsx")
violet_rank_df['Rank'].mean()
# Out:
# 214.04166666666666

# %%
daisy_rank_df = pd.read_excel("Daisy - Name Ranking.xlsx")
daisy_rank_df['Rank'].mean()
# Out:
# 155.625

# %%
iris_rank_df = pd.read_excel("Iris - Name Ranking.xlsx")
iris_rank_df['Rank'].mean()
# Out:
# 261.125

# %%
jasmine_rank_df = pd.read_excel("Jasmine - Name Ranking.xlsx")
jasmine_rank_df['Rank'].mean()
# Out:
# 85.125

# %%
aries_df = df[df['Name'] == 'Aries']
aries_df
# Out:
#          Year   Name Sex  Count
# 709387   1970  Aries   M      9
# 726129   1971  Aries   M      5
# 734157   1972  Aries   F      6
# 741520   1972  Aries   M      5
# 747454   1973  Aries   F     10
# ...       ...    ...  ..    ...
# 2040103  2021  Aries   M    248
# 2055224  2022  Aries   F     98
# 2071774  2022  Aries   M    274
# 2087012  2023  Aries   F    107
# 2103476  2023  Aries   M    319
#
# [102 rows x 4 columns]

# %%
aries_chart = alt.Chart(aries_df).mark_point().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0,300])),
    color='Sex',
).interactive()

aries_chart
# Out:
# alt.Chart(...)

# %%
aries_chart = alt.Chart(aries_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1960, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0,300])),
    color='Sex',
).interactive()

aries_chart
# Out:
# alt.Chart(...)

# %%
taurus_df =  df[df['Name'] == 'Taurus']
taurus_df
# Out:
#          Year    Name Sex  Count
# 668252   1967  Taurus   M     10
# 682923   1968  Taurus   M      5
# 694104   1969  Taurus   M     14
# 708375   1970  Taurus   M     17
# 722950   1971  Taurus   M     26
# ...       ...     ...  ..    ...
# 1981693  2019  Taurus   M     16
# 2014953  2020  Taurus   M     11
# 2044489  2021  Taurus   M     18
# 2081572  2022  Taurus   M      7
# 2110335  2023  Taurus   M     11
#
# [65 rows x 4 columns]

# %%
taurus_chart = alt.Chart(taurus_df).mark_point().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1960, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0,300])),
    color='Sex',
).interactive()

taurus_chart
# Out:
# alt.Chart(...)

# %%
taurus_chart = alt.Chart(taurus_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1960, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0,300])),
    color='Sex',
).interactive()

taurus_chart
# Out:
# alt.Chart(...)

# %%
gemini_df =  df[df['Name'] == 'Gemini']
gemini_df
# Out:
#          Year    Name Sex  Count
# 637141   1965  Gemini   F     13
# 690835   1969  Gemini   F      5
# 757411   1973  Gemini   M      5
# 763835   1974  Gemini   F      9
# 782503   1975  Gemini   F      6
# ...       ...     ...  ..    ...
# 2045307  2021  Gemini   M     14
# 2060010  2022  Gemini   F     17
# 2080124  2022  Gemini   M      8
# 2092898  2023  Gemini   F     14
# 2109320  2023  Gemini   M     13
#
# [67 rows x 4 columns]

# %%
gemini_chart = alt.Chart(gemini_df).mark_point().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1960, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0,300])),
    color='Sex',
).interactive()

gemini_chart
# Out:
# alt.Chart(...)

# %%
gemini_chart = alt.Chart(gemini_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1960, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0,300])),
    color='Sex',
).interactive()

gemini_chart
# Out:
# alt.Chart(...)

# %%
leo_df =  df[df['Name'] == 'Leo']
leo_df
# Out:
#          Year Name Sex  Count
# 798      1880  Leo   F      6
# 1034     1880  Leo   M    147
# 2789     1881  Leo   F      6
# 3040     1881  Leo   M    122
# 5060     1882  Leo   M    146
# ...       ...  ...  ..    ...
# 2039216  2021  Leo   M   7783
# 2057643  2022  Leo   F     32
# 2070924  2022  Leo   M   8250
# 2089954  2023  Leo   F     28
# 2102708  2023  Leo   M   8120
#
# [265 rows x 4 columns]

# %%
leo_chart = alt.Chart(leo_df).mark_point().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0,5000])),
    color='Sex',
).interactive()

leo_chart
# Out:
# alt.Chart(...)

# %%
leo_chart = alt.Chart(leo_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0,5000])),
    color='Sex',
).interactive()

leo_chart
# Out:
# alt.Chart(...)

# %%
libra_df =  df[df['Name'] == 'Libra']
libra_df
# Out:
#         Year   Name Sex  Count
# 677700  1968  Libra   F      5
# 701670  1970  Libra   F     11
# 715397  1971  Libra   F     16
# 731036  1972  Libra   F     14
# 745120  1973  Libra   F     24
# 760808  1974  Libra   F     25
# 777392  1975  Libra   F     22
# 793586  1976  Libra   F     33
# 812682  1977  Libra   F     17
# 831091  1978  Libra   F     16
# 849477  1979  Libra   F     16
# 872662  1980  Libra   F      7
# 892089  1981  Libra   F      7
# 953442  1984  Libra   F      5

# %%
libra_chart = alt.Chart(libra_df).mark_point().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1960, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0,300])),
    color='Sex',
).interactive()

libra_chart
# Out:
# alt.Chart(...)

# %%
libra_chart = alt.Chart(libra_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1960, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0,300])),
    color='Sex',
).interactive()

libra_chart
# Out:
# alt.Chart(...)

# %%
scorpio_df =  df[df['Name'] == 'Scorpio']
scorpio_df
# Out:
#          Year     Name Sex  Count
# 900080   1981  Scorpio   M      9
# 922451   1982  Scorpio   M      5
# 938092   1983  Scorpio   M     13
# 960420   1984  Scorpio   M      6
# 999740   1986  Scorpio   M      8
# 1023517  1987  Scorpio   M      5
# 1067471  1989  Scorpio   M      7
# 1118142  1991  Scorpio   M      6
# 1144895  1992  Scorpio   M      5
# 1167660  1993  Scorpio   M      8

# %%
scorpio_chart = alt.Chart(scorpio_df).mark_point().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0,50])),
    color='Sex',
).interactive()

scorpio_chart
# Out:
# alt.Chart(...)

# %%
scorpio_chart = alt.Chart(scorpio_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1960, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0,300])),
    color='Sex',
).interactive()

scorpio_chart
# Out:
# alt.Chart(...)

# %%
aquarius_df =  df[df['Name'] == 'Aquarius']
aquarius_df
# Out:
#          Year      Name Sex  Count
# 703143   1970  Aquarius   F      7
# 718954   1971  Aquarius   F      6
# 726127   1971  Aquarius   M      5
# 735192   1972  Aquarius   F      5
# 764871   1974  Aquarius   F      7
# 782219   1975  Aquarius   F      6
# 795295   1976  Aquarius   F     15
# 818263   1977  Aquarius   F      5
# 833133   1978  Aquarius   F      9
# 855248   1979  Aquarius   F      5
# 913551   1982  Aquarius   F      5
# 931730   1983  Aquarius   F      6
# 960596   1984  Aquarius   M      5
# 1013749  1987  Aquarius   F      5
# 1035675  1988  Aquarius   F      5
# 1079185  1990  Aquarius   F      8
# 1103995  1991  Aquarius   F      8
# 1130287  1992  Aquarius   F      7
# 1142804  1992  Aquarius   M      6
# 1150582  1993  Aquarius   F     17
# 1167202  1993  Aquarius   M      8
# 1183017  1994  Aquarius   F      6
# 1194703  1994  Aquarius   M      6
# 1204196  1995  Aquarius   F     12
# 1221817  1995  Aquarius   M      5
# 1230819  1996  Aquarius   F     11
# ...

# %%
aquarius_chart = alt.Chart(aquarius_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1960, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0,300])),
    color='Sex',
).interactive()

aquarius_chart
# Out:
# alt.Chart(...)

# %%
daria_df = df[df['Name'] == 'Daria']
daria_df
# Out:
#          Year   Name Sex  Count
# 124150   1915  Daria   F      5
# 153081   1918  Daria   F      6
# 205881   1923  Daria   F      7
# 215303   1924  Daria   F     12
# 227081   1925  Daria   F      8
# ...       ...    ...  ..    ...
# 1959734  2019  Daria   F    113
# 1991949  2020  Daria   F    100
# 2023562  2021  Daria   F     96
# 2055030  2022  Daria   F    114
# 2087056  2023  Daria   F    104
#
# [100 rows x 4 columns]

# %%
female_protag_df = daria_df[daria_df['Year'] >= 1960]
female_protag_df
# Out:
#          Year   Name Sex  Count
# 573445   1960  Daria   F    133
# 585380   1961  Daria   F    133
# 597525   1962  Daria   F    141
# 609752   1963  Daria   F    135
# 622185   1964  Daria   F    106
# ...       ...    ...  ..    ...
# 1959734  2019  Daria   F    113
# 1991949  2020  Daria   F    100
# 2023562  2021  Daria   F     96
# 2055030  2022  Daria   F    114
# 2087056  2023  Daria   F    104
#
# [65 rows x 4 columns]

# %%
daria_chart = alt.Chart(daria_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=('Count'),
    color='Sex',
).interactive()

daria_chart
# Out:
# alt.Chart(...)

# %%
mulan_df = df[df['Name'] == 'Mulan']
mulan_df = mulan_df[mulan_df['Sex'] == 'F']
mulan_df
# Out:
#          Year   Name Sex  Count
# 1282875  1998  Mulan   F     16
# 1316756  1999  Mulan   F      7
# 1347496  2000  Mulan   F      6
# 1374551  2001  Mulan   F      8
# 1407961  2002  Mulan   F      6
# 1505261  2005  Mulan   F      5
# 1530684  2006  Mulan   F     10
# 1573197  2007  Mulan   F      5
# 1601994  2008  Mulan   F      8
# 1634108  2009  Mulan   F     11
# 1668636  2010  Mulan   F     11
# 1705484  2011  Mulan   F      8
# 1732258  2012  Mulan   F     23
# 1765290  2013  Mulan   F     27
# 1798781  2014  Mulan   F     26
# 1832592  2015  Mulan   F     23
# 1864476  2016  Mulan   F     32
# 1897815  2017  Mulan   F     29
# 1928795  2018  Mulan   F     53
# 1961131  2019  Mulan   F     50
# 1992498  2020  Mulan   F     71
# 2024787  2021  Mulan   F     50
# 2056112  2022  Mulan   F     59
# 2088149  2023  Mulan   F     56

# %%
female_protag_df = pd.concat([female_protag_df, mulan_df], ignore_index=True)
female_protag_df
# Out:
#     Year   Name Sex  Count
# 0   1960  Daria   F    133
# 1   1961  Daria   F    133
# 2   1962  Daria   F    141
# 3   1963  Daria   F    135
# 4   1964  Daria   F    106
# ..   ...    ...  ..    ...
# 84  2019  Mulan   F     50
# 85  2020  Mulan   F     71
# 86  2021  Mulan   F     50
# 87  2022  Mulan   F     59
# 88  2023  Mulan   F     56
#
# [89 rows x 4 columns]

# %%
mulan_chart = alt.Chart(mulan_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=('Count'),
    color='Sex',
).interactive()

mulan_chart
# Out:
# alt.Chart(...)

# %%
kim_df = df[df['Name'] == 'Kim']
kim_df
# Out:
#          Year Name Sex  Count
# 104615   1912  Kim   M      5
# 110875   1913  Kim   M      7
# 115666   1914  Kim   F      5
# 128804   1915  Kim   M      5
# 158771   1918  Kim   M      5
# ...       ...  ...  ..    ...
# 2048473  2021  Kim   M      8
# 2057022  2022  Kim   F     40
# 2078922  2022  Kim   M     10
# 2089085  2023  Kim   F     38
# 2111282  2023  Kim   M      9
#
# [208 rows x 4 columns]

# %%
kim_chart = alt.Chart(kim_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=('Count'),
    color='Sex',
).interactive()

kim_chart
# Out:
# alt.Chart(...)

# %%
daphne_df = df[df['Name'] == 'Daphne']
daphne_df = daphne_df[daphne_df['Sex'] == 'F']
daphne_df = daphne_df[daphne_df['Year'] >= 1960]
daphne_df
# Out:
#          Year    Name Sex  Count
# 573096   1960  Daphne   F    295
# 584822   1961  Daphne   F    670
# 596899   1962  Daphne   F   1132
# 609155   1963  Daphne   F    926
# 621476   1964  Daphne   F    766
# ...       ...     ...  ..    ...
# 1958366  2019  Daphne   F    734
# 1990454  2020  Daphne   F    751
# 2021846  2021  Daphne   F   1101
# 2053520  2022  Daphne   F   1129
# 2085398  2023  Daphne   F   1257
#
# [64 rows x 4 columns]

# %%
female_protag_df = pd.concat([female_protag_df, daphne_df], ignore_index=True)
female_protag_df
# Out:
#      Year    Name Sex  Count
# 0    1960   Daria   F    133
# 1    1961   Daria   F    133
# 2    1962   Daria   F    141
# 3    1963   Daria   F    135
# 4    1964   Daria   F    106
# ..    ...     ...  ..    ...
# 148  2019  Daphne   F    734
# 149  2020  Daphne   F    751
# 150  2021  Daphne   F   1101
# 151  2022  Daphne   F   1129
# 152  2023  Daphne   F   1257
#
# [153 rows x 4 columns]

# %%
daphne_chart = alt.Chart(daphne_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=('Count'),
    color='Sex',
).interactive()

daphne_chart
# Out:
# alt.Chart(...)

# %%
eliza_df = df[df['Name'] == 'Eliza']
eliza_df = eliza_df[eliza_df['Year'] >= 1960]
eliza_df
# Out:
#          Year   Name Sex  Count
# 573600   1960  Eliza   F    100
# 585606   1961  Eliza   F     91
# 597759   1962  Eliza   F     93
# 609955   1963  Eliza   F     97
# 622330   1964  Eliza   F     85
# ...       ...    ...  ..    ...
# 2021668  2021  Eliza   F   2480
# 2050315  2021  Eliza   M      6
# 2053364  2022  Eliza   F   2328
# 2085273  2023  Eliza   F   2350
# 2112677  2023  Eliza   M      7
#
# [70 rows x 4 columns]

# %%
female_protag_df = pd.concat([female_protag_df, eliza_df], ignore_index=True)
female_protag_df
# Out:
#      Year   Name Sex  Count
# 0    1960  Daria   F    133
# 1    1961  Daria   F    133
# 2    1962  Daria   F    141
# 3    1963  Daria   F    135
# 4    1964  Daria   F    106
# ..    ...    ...  ..    ...
# 218  2021  Eliza   F   2480
# 219  2021  Eliza   M      6
# 220  2022  Eliza   F   2328
# 221  2023  Eliza   F   2350
# 222  2023  Eliza   M      7
#
# [223 rows x 4 columns]

# %%
eliza_chart = alt.Chart(eliza_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=('Count'),
    color='Sex',
).interactive()

eliza_chart
# Out:
# alt.Chart(...)

# %%
velma_df = df[df['Name'] == 'Velma']
velma_df = velma_df[velma_df['Sex'] == 'F']
velma_df = velma_df[velma_df['Year'] >= 1960]
velma_df
# Out:
#          Year   Name Sex  Count
# 572931   1960  Velma   F    558
# 584879   1961  Velma   F    524
# 597079   1962  Velma   F    464
# 609327   1963  Velma   F    407
# 621620   1964  Velma   F    394
# ...       ...    ...  ..    ...
# 1966025  2019  Velma   F     14
# 1997568  2020  Velma   F     15
# 2029149  2021  Velma   F     15
# 2058519  2022  Velma   F     25
# 2090866  2023  Velma   F     22
#
# [64 rows x 4 columns]

# %%
female_protag_df = pd.concat([female_protag_df, velma_df], ignore_index=True)
female_protag_df
# Out:
#      Year   Name Sex  Count
# 0    1960  Daria   F    133
# 1    1961  Daria   F    133
# 2    1962  Daria   F    141
# 3    1963  Daria   F    135
# 4    1964  Daria   F    106
# ..    ...    ...  ..    ...
# 282  2019  Velma   F     14
# 283  2020  Velma   F     15
# 284  2021  Velma   F     15
# 285  2022  Velma   F     25
# 286  2023  Velma   F     22
#
# [287 rows x 4 columns]

# %%
female_protag_df.to_csv('female_protag_df.csv', index=False)

# %%
female_protag_df.to_excel('female_protag_df.xlsx', index=False)

# %%
velma_chart = alt.Chart(velma_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=('Count'),
    color='Sex',
).interactive()

velma_chart
# Out:
# alt.Chart(...)

# %%
bonnie_df = df[df['Name'] == 'Bonnie']
bonnie_df = bonnie_df[bonnie_df['Sex'] == 'F']
bonnie_df
# Out:
#          Year    Name Sex  Count
# 451      1880  Bonnie   F     14
# 2316     1881  Bonnie   F     25
# 4351     1882  Bonnie   F     19
# 6472     1883  Bonnie   F     21
# 8495     1884  Bonnie   F     32
# ...       ...     ...  ..    ...
# 1958577  2019  Bonnie   F    449
# 1990646  2020  Bonnie   F    480
# 2022070  2021  Bonnie   F    601
# 2053771  2022  Bonnie   F    586
# 2085659  2023  Bonnie   F    603
#
# [144 rows x 4 columns]

# %%
bonnie_chart = alt.Chart(bonnie_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 11000])),
    color='Sex',
).interactive()

bonnie_chart
# Out:
# alt.Chart(...)

# %%
clyde_df = df[df['Name'] == 'Clyde']
clyde_df = clyde_df[clyde_df['Sex'] == 'M']
clyde_df
# Out:
#          Year   Name Sex  Count
# 1013     1880  Clyde   M    221
# 3005     1881  Clyde   M    232
# 5023     1882  Clyde   M    293
# 7164     1883  Clyde   M    336
# 9372     1884  Clyde   M    345
# ...       ...    ...  ..    ...
# 1976706  2019  Clyde   M    299
# 2008240  2020  Clyde   M    347
# 2039916  2021  Clyde   M    352
# 2071590  2022  Clyde   M    388
# 2103409  2023  Clyde   M    367
#
# [144 rows x 4 columns]

# %%
clyde_chart = alt.Chart(clyde_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 11000])),
    color='Sex',
).interactive()

clyde_chart
# Out:
# alt.Chart(...)

# %%
romeo_df = df[df['Name'] == 'Romeo']
romeo_df = romeo_df[romeo_df['Sex'] == 'M']
romeo_df
# Out:
#          Year   Name Sex  Count
# 1675     1880  Romeo   M      8
# 25142    1890  Romeo   M      7
# 30434    1892  Romeo   M     11
# 33825    1893  Romeo   M      5
# 36487    1894  Romeo   M      7
# ...       ...    ...  ..    ...
# 1976275  2019  Romeo   M    969
# 2007903  2020  Romeo   M    816
# 2039535  2021  Romeo   M    927
# 2071225  2022  Romeo   M   1038
# 2102983  2023  Romeo   M   1123
#
# [133 rows x 4 columns]

# %%
romeo_chart = alt.Chart(romeo_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 11000])),
    color='Sex',
).interactive()

romeo_chart
# Out:
# alt.Chart(...)

# %%
juliet_df = df[df['Name'] == 'Juliet']
juliet_df = juliet_df[juliet_df['Sex'] == 'F']
juliet_df
# Out:
#          Year    Name Sex  Count
# 562      1880  Juliet   F     10
# 2603     1881  Juliet   F      9
# 4708     1882  Juliet   F      7
# 6691     1883  Juliet   F     10
# 8745     1884  Juliet   F     13
# ...       ...     ...  ..    ...
# 1958200  2019  Juliet   F   1230
# 1990346  2020  Juliet   F   1035
# 2021852  2021  Juliet   F   1078
# 2053535  2022  Juliet   F   1072
# 2085449  2023  Juliet   F   1061
#
# [144 rows x 4 columns]

# %%
juliet_chart = alt.Chart(juliet_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 11000])),
    color='Sex',
).interactive()

juliet_chart
# Out:
# alt.Chart(...)

# %%
sally_df = df[df['Name'] == 'Sally']
sally_df = sally_df[sally_df['Sex'] == 'F']
sally_df
# Out:
#          Year   Name Sex  Count
# 165      1880  Sally   F     80
# 2169     1881  Sally   F     79
# 4098     1882  Sally   F     95
# 6263     1883  Sally   F     73
# 8330     1884  Sally   F     95
# ...       ...    ...  ..    ...
# 1959332  2019  Sally   F    161
# 1991207  2020  Sally   F    200
# 2022782  2021  Sally   F    192
# 2054587  2022  Sally   F    174
# 2086487  2023  Sally   F    170
#
# [144 rows x 4 columns]

# %%
sally_chart = alt.Chart(sally_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 11000])),
    color='Sex',
).interactive()

sally_chart
# Out:
# alt.Chart(...)

# %%
harry_df = df[df['Name'] == 'Harry']
harry_df = harry_df[harry_df['Sex'] == 'M']
harry_df
# Out:
#          Year   Name Sex  Count
# 953      1880  Harry   M   2152
# 2949     1881  Harry   M   2002
# 4973     1882  Harry   M   2232
# 7126     1883  Harry   M   2110
# 9328     1884  Harry   M   2323
# ...       ...    ...  ..    ...
# 1976576  2019  Harry   M    414
# 2008245  2020  Harry   M    344
# 2039907  2021  Harry   M    357
# 2071597  2022  Harry   M    379
# 2103472  2023  Harry   M    322
#
# [144 rows x 4 columns]

# %%
harry_chart = alt.Chart(harry_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1900, 2023])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 11000])),
    color='Sex',
).interactive()

harry_chart
# Out:
# alt.Chart(...)

# %%
rory_df = df[df['Name'] == 'Rory']
rory_df = rory_df[rory_df['Sex'] == 'F']
femaleduo_df = rory_df[rory_df['Year'] >= 1980]
femaleduo_df
# Out:
#          Year  Name Sex  Count
# 867115   1980  Rory   F     28
# 886771   1981  Rory   F     26
# 905295   1982  Rory   F     42
# 925026   1983  Rory   F     40
# 944556   1984  Rory   F     38
# 964097   1985  Rory   F     39
# 984613   1986  Rory   F     32
# 1005711  1987  Rory   F     27
# 1026758  1988  Rory   F     34
# 1048963  1989  Rory   F     39
# 1073379  1990  Rory   F     31
# 1098125  1991  Rory   F     31
# 1123473  1992  Rory   F     29
# 1149496  1993  Rory   F     24
# 1174404  1994  Rory   F     35
# 1200762  1995  Rory   F     30
# 1226207  1996  Rory   F     40
# 1252384  1997  Rory   F     45
# 1279199  1998  Rory   F     53
# 1306963  1999  Rory   F     59
# 1335038  2000  Rory   F     85
# 1364189  2001  Rory   F    142
# 1394234  2002  Rory   F    187
# 1424677  2003  Rory   F    234
# 1456021  2004  Rory   F    201
# 1488107  2005  Rory   F    198
# 1520593  2006  Rory   F    231
# 1554674  2007  Rory   F    245
# 1589543  2008  Rory   F    275
# ...

# %%
rory_chart = alt.Chart(rory_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1980, 2020])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 2500])),
    color='Sex',
).interactive()

rory_chart
# Out:
# alt.Chart(...)

# %%
lorelai_df = df[df['Name'] == 'Lorelai']
lorelai_df = lorelai_df[lorelai_df['Sex'] == 'F']
lorelai_df = lorelai_df[lorelai_df['Year'] >= 1980]
lorelai_df
# Out:
#          Year     Name Sex  Count
# 1368563  2001  Lorelai   F     20
# 1395484  2002  Lorelai   F     68
# 1425741  2003  Lorelai   F     87
# 1456783  2004  Lorelai   F     99
# 1488161  2005  Lorelai   F    187
# 1520493  2006  Lorelai   F    262
# 1554472  2007  Lorelai   F    321
# 1589458  2008  Lorelai   F    312
# 1624441  2009  Lorelai   F    363
# 1659134  2010  Lorelai   F    371
# 1693282  2011  Lorelai   F    340
# 1727151  2012  Lorelai   F    378
# 1760990  2013  Lorelai   F    338
# 1794337  2014  Lorelai   F    338
# 1827466  2015  Lorelai   F    439
# 1860604  2016  Lorelai   F    479
# 1893585  2017  Lorelai   F    567
# 1926280  2018  Lorelai   F    541
# 1958487  2019  Lorelai   F    547
# 1990565  2020  Lorelai   F    574
# 2022079  2021  Lorelai   F    589
# 2053722  2022  Lorelai   F    654
# 2085629  2023  Lorelai   F    650

# %%
femaleduo_df = pd.concat([femaleduo_df, lorelai_df], ignore_index=True)
femaleduo_df
# Out:
#     Year     Name Sex  Count
# 0   1980     Rory   F     28
# 1   1981     Rory   F     26
# 2   1982     Rory   F     42
# 3   1983     Rory   F     40
# 4   1984     Rory   F     38
# ..   ...      ...  ..    ...
# 85  2019  Lorelai   F    547
# 86  2020  Lorelai   F    574
# 87  2021  Lorelai   F    589
# 88  2022  Lorelai   F    654
# 89  2023  Lorelai   F    650
#
# [90 rows x 4 columns]

# %%
lorelai_chart = alt.Chart(lorelai_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1980, 2020])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 2500])),
    color='Sex',
).interactive()

lorelai_chart
# Out:
# alt.Chart(...)

# %%
tia_df = df[df['Name'] == 'Tia']
tia_df = tia_df[tia_df['Sex'] == 'F']
tia_df = tia_df[tia_df['Year'] >= 1980]
tia_df
# Out:
#          Year Name Sex  Count
# 864229   1980  Tia   F   1114
# 883701   1981  Tia   F   1010
# 903158   1982  Tia   F   1182
# 922900   1983  Tia   F    913
# 942355   1984  Tia   F    788
# 961875   1985  Tia   F    781
# 982008   1986  Tia   F    678
# 1002660  1987  Tia   F    722
# 1024095  1988  Tia   F    675
# 1046464  1989  Tia   F    717
# 1070188  1990  Tia   F    907
# 1094863  1991  Tia   F   1069
# 1120001  1992  Tia   F    964
# 1145437  1993  Tia   F    952
# 1171411  1994  Tia   F    922
# 1197382  1995  Tia   F   1015
# 1223465  1996  Tia   F   1066
# 1249911  1997  Tia   F    984
# 1276907  1998  Tia   F    957
# 1304849  1999  Tia   F    867
# 1333465  2000  Tia   F    701
# 1363257  2001  Tia   F    674
# 1393551  2002  Tia   F    667
# 1424170  2003  Tia   F    612
# 1455388  2004  Tia   F    576
# 1487493  2005  Tia   F    521
# 1520100  2006  Tia   F    484
# 1554339  2007  Tia   F    395
# 1589446  2008  Tia   F    318
# 1624613  2009  Tia   F    281
# ...

# %%
femaleduo_df = pd.concat([femaleduo_df, tia_df], ignore_index=True)
femaleduo_df
# Out:
#      Year  Name Sex  Count
# 0    1980  Rory   F     28
# 1    1981  Rory   F     26
# 2    1982  Rory   F     42
# 3    1983  Rory   F     40
# 4    1984  Rory   F     38
# ..    ...   ...  ..    ...
# 129  2019   Tia   F    160
# 130  2020   Tia   F    161
# 131  2021   Tia   F    132
# 132  2022   Tia   F    112
# 133  2023   Tia   F    136
#
# [134 rows x 4 columns]

# %%
tia_chart = alt.Chart(tia_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1990, 2020])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 2500])),
    color='Sex',
).interactive()

tia_chart
# Out:
# alt.Chart(...)

# %%
tamera_df = df[df['Name'] == 'Tamera']
tamera_df = tamera_df[tamera_df['Sex'] == 'F']
tamera_df = tamera_df[tamera_df['Year'] >= 1980]
tamera_df
# Out:
#          Year    Name Sex  Count
# 864878   1980  Tamera   F    175
# 884340   1981  Tamera   F    172
# 903893   1982  Tamera   F    156
# 923608   1983  Tamera   F    151
# 943083   1984  Tamera   F    138
# 962635   1985  Tamera   F    138
# 982703   1986  Tamera   F    145
# 1003546  1987  Tamera   F    117
# 1025186  1988  Tamera   F     95
# 1047924  1989  Tamera   F     74
# 1071662  1990  Tamera   F     82
# 1096310  1991  Tamera   F     86
# 1121901  1992  Tamera   F     62
# 1147212  1993  Tamera   F     67
# 1172148  1994  Tamera   F    179
# 1197868  1995  Tamera   F    270
# 1223933  1996  Tamera   F    286
# 1250443  1997  Tamera   F    252
# 1277414  1998  Tamera   F    260
# 1305415  1999  Tamera   F    232
# 1334239  2000  Tamera   F    170
# 1364367  2001  Tamera   F    122
# 1394557  2002  Tamera   F    133
# 1425220  2003  Tamera   F    127
# 1456806  2004  Tamera   F     98
# 1488849  2005  Tamera   F    102
# 1521806  2006  Tamera   F     83
# ...

# %%
femaleduo_df = pd.concat([femaleduo_df, tamera_df], ignore_index=True)
femaleduo_df
# Out:
#      Year    Name Sex  Count
# 0    1980    Rory   F     28
# 1    1981    Rory   F     26
# 2    1982    Rory   F     42
# 3    1983    Rory   F     40
# 4    1984    Rory   F     38
# ..    ...     ...  ..    ...
# 173  2019  Tamera   F     37
# 174  2020  Tamera   F     20
# 175  2021  Tamera   F     22
# 176  2022  Tamera   F     20
# 177  2023  Tamera   F     25
#
# [178 rows x 4 columns]

# %%
tamera_chart = alt.Chart(tamera_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1990, 2020])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 2500])),
    color='Sex',
).interactive()

tamera_chart
# Out:
# alt.Chart(...)

# %%
# sansa_df = df[df['Name'] == 'Sansa']
# sansa_df = sansa_df[sansa_df['Sex'] == 'F']
# sansa_df

# %%
# sansa_chart = alt.Chart(sansa_df).mark_line().encode(
#     x=alt.X('Year', scale=alt.Scale(domain=[1990, 2023])),
#     y=alt.Y('Count', scale=alt.Scale(domain=[0, 1200])),
#     color='Sex',
# ).interactive()

# sansa_chart

# %%
# arya_df = df[df['Name'] == 'Arya']
# arya_df = arya_df[arya_df['Sex'] == 'F']
# arya_df

# %%
# arya_chart = alt.Chart(arya_df).mark_line().encode(
#     x=alt.X('Year', scale=alt.Scale(domain=[1990, 2023])),
#     y=alt.Y('Count', scale=alt.Scale(domain=[0, 1200])),
#     color='Sex',
# ).interactive()

# arya_chart

# %%
cagney_df = df[df['Name'] == 'Cagney']
cagney_df = cagney_df[cagney_df['Sex'] == 'F']
cagney_df = cagney_df[cagney_df['Year'] >= 1980]
cagney_df
# Out:
#          Year    Name Sex  Count
# 913632   1982  Cagney   F      5
# 928504   1983  Cagney   F     11
# 947040   1984  Cagney   F     14
# 964513   1985  Cagney   F     31
# 984283   1986  Cagney   F     37
# 1006630  1987  Cagney   F     19
# 1031510  1988  Cagney   F      9
# 1081494  1990  Cagney   F      6
# 1108054  1991  Cagney   F      5
# 1129315  1992  Cagney   F      8
# 1158915  1993  Cagney   F      5
# 1235268  1996  Cagney   F      6
# 1260660  1997  Cagney   F      7
# 1287916  1998  Cagney   F      7
# 1346495  2000  Cagney   F      6
# 1471430  2004  Cagney   F      5
# 1641445  2009  Cagney   F      5

# %%
femaleduo_df = pd.concat([femaleduo_df, cagney_df], ignore_index=True)
femaleduo_df
# Out:
#      Year    Name Sex  Count
# 0    1980    Rory   F     28
# 1    1981    Rory   F     26
# 2    1982    Rory   F     42
# 3    1983    Rory   F     40
# 4    1984    Rory   F     38
# ..    ...     ...  ..    ...
# 190  1997  Cagney   F      7
# 191  1998  Cagney   F      7
# 192  2000  Cagney   F      6
# 193  2004  Cagney   F      5
# 194  2009  Cagney   F      5
#
# [195 rows x 4 columns]

# %%
cagney_chart = alt.Chart(cagney_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1980, 2020])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 2500])),
    color='Sex',
).interactive()

cagney_chart
# Out:
# alt.Chart(...)

# %%
lacey_df = df[df['Name'] == 'Lacey']
lacey_df = lacey_df[lacey_df['Sex'] == 'F']
lacey_df
# Out:
#          Year   Name Sex  Count
# 18881    1888  Lacey   F      5
# 64199    1903  Lacey   F      6
# 122998   1915  Lacey   F      8
# 132811   1916  Lacey   F      7
# 142292   1917  Lacey   F      8
# ...       ...    ...  ..    ...
# 1958590  2019  Lacey   F    444
# 1990753  2020  Lacey   F    391
# 2022365  2021  Lacey   F    346
# 2054117  2022  Lacey   F    316
# 2085916  2023  Lacey   F    369
#
# [98 rows x 4 columns]

# %%
femaleduo_df = pd.concat([femaleduo_df, lacey_df], ignore_index=True)
femaleduo_df
# Out:
#      Year   Name Sex  Count
# 0    1980   Rory   F     28
# 1    1981   Rory   F     26
# 2    1982   Rory   F     42
# 3    1983   Rory   F     40
# 4    1984   Rory   F     38
# ..    ...    ...  ..    ...
# 234  2019  Lacey   F    444
# 235  2020  Lacey   F    391
# 236  2021  Lacey   F    346
# 237  2022  Lacey   F    316
# 238  2023  Lacey   F    369
#
# [239 rows x 4 columns]

# %%
femaleduo_df.to_excel("femaleduo_df.xlsx", index=False)

# %%
femaleduo_df.to_csv("femaleduo_df.csv", index=False)

# %%
lacey_chart = alt.Chart(lacey_df).mark_line().encode(
    x=alt.X('Year', scale=alt.Scale(domain=[1800, 2020])),
    y=alt.Y('Count', scale=alt.Scale(domain=[0, 2500])),
    color='Sex',
).interactive()

lacey_chart
# Out:
# alt.Chart(...)
